# %% [markdown]
# # 14장 - 텐서플로의 구조 자세히 알아보기 (part 2)

# %%
import numpy as np
import tensorflow as tf
import pandas as pd

from IPython.display import Image

# %%
print(tf.__version__)
print(np.__version__)
print(pd.__version__)
# Out:
# 2.5.0
# 1.19.5
# 1.4.3

# %% [markdown]
# # 텐서플로 추정기

# %% [markdown]
# 이 절에서는 방향을 바꾸어 텐서플로 추정기(Estimator)를 사용한다.
# `tf.estimator` API는 훈련, 예측(추론), 평가와 같은 머신 러닝 작업의 기본 단계를 캡슐화한다. 추정기는 이 장에서 다룬 다른 방법에 비해 캡슐화가 잘되어 있을 뿐만 아니라 확장성도 높다.
# `tf.estimator` API는 주요 코드를 변경하지 않고 다양한 플랫폼에서 모델을 실행할 수 있도록 지원한다. 상용 애플리케이션의 소위 '제품화 단계'에 적합하다.
# 또한, 텐서플로는 널리 사용하는 일부 머신 러닝과 딥러닝 구조를 미리 구현한 추정기를 제공한다. 특정 방법이 어떤 데이터셋이나 문제에 적용할 수 있는지 빠르게 확인하는 것과 같은 비교 연구에 유용하다.
#
# 사전에 준비된 추정기 사용하는 단계
# - **단계 1**: 데이터 로딩을 위해 입력 함수 정의하기
# - **단계 2**: 추정기와 데이터 사이를 연결하기 위해 특성 열 정의하기
# - **단계 3**: 추정기 객체를 만들거나 케라스 모델을 추정기로 바꾸기
# - **단계 4**: 추정기 사용하기: train() evalueate() predict()

# %%
tf.random.set_seed(1)
np.random.seed(1)

# %% [markdown]
# ## 특성 열 사용

# %% [markdown]
# 머신 러닝과 딥러닝 애플리케이션에서 다양한 종류의 특성을 볼 수 있다. 연속 특성, 순서가 없는 범주형 특성, 순서가 있는 범주형 특성이 있다.
# 4장에서 다양한 종류의 특성을 다루는 방법을 배웠다. 수치형 데이터는 연속적이거나 이산적일 수 있지만 텐서플로 API에서는 '수치형' 데이터는 특별히 부동 소수 형태의 연속적인 데이터를 나타낸다.
#
# 이따금 특성 집합은 다양한 특성 종류가 혼합되어 구성된다. 텐서플로 추정기는 이런 모든 종류의 특성을 다루도록 설계되었지만 각 특성이 추정기에서 어떻게 해석되어야 하는지 지정해 주어야 한다.

# %%
Image(url='https://git.io/JL56E', width=700)
# Out:
# <img src="https://git.io/JL56E" width="700"/>

# %% [markdown]
# 위 그림에 있는 특성(model year, cylinders, displacement, horsepower, weigth, acceleration, origin)은 Auto MPG 데이터셋에서 가져온 것이다.
# 이 데이터셋은 널리 사용되는 머신 러닝 벤치마크 데이터셋으로 갤런당 마일(MP) 단위로 자동차의 연료 효율성을 예측하는 문제이다.
#
# Auto MPG 데이터셋 중 다섯 개의 특성(cylinders, displacement, horsepower, weight, accleration)은 수치형(여기서는 연속적인)특성이다.
# model year는 순서가 있는 범주형 특성으로 볼 수 있다. 마지막으로 origin은 순서가 없는 특성이며 각각 US, 유럽, 일본을 의미하는 1, 2, 3 세 개의 값이 가능하다.
#
# 먼저 데이터를 로드한 후 훈련 데이터셋과 테스트 데이터셋으로 나누고 연속적인 특성에 표준화를 적용하는 것과 같은 필수적인 전처리 단계를 수행해보자.

# %%
dataset_path = tf.keras.utils.get_file("auto-mpg.data", 
                                       ("http://archive.ics.uci.edu/ml/machine-learning-databases"
                                        "/auto-mpg/auto-mpg.data"))

column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower',
                'Weight', 'Acceleration', 'ModelYear', 'Origin']

df = pd.read_csv(dataset_path, names=column_names,
                 na_values = "?", comment='\t',
                 sep=" ", skipinitialspace=True)

df.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      ModelYear  Origin
# 393         82       1
# 394         82       2
# 395         82       1
# 396         82       1
# 397         82       1

# %%
## NA 열 삭제
print(df.isna().sum())

df = df.dropna()
df = df.reset_index(drop=True)
df.tail()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# ModelYear       0
# Origin          0
# dtype: int64
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 387  27.0          4         140.0        86.0  2790.0          15.6
# 388  44.0          4          97.0        52.0  2130.0          24.6
# 389  32.0          4         135.0        84.0  2295.0          11.6
# 390  28.0          4         120.0        79.0  2625.0          18.6
# 391  31.0          4         119.0        82.0  2720.0          19.4
#
#      ModelYear  Origin
# 387         82       1
# 388         82       2
# 389         82       1
# 390         82       1
# 391         82       1

# %%
## 훈련/테스트 분할
import sklearn
import sklearn.model_selection


df_train, df_test = sklearn.model_selection.train_test_split(df, train_size=0.8)
train_stats = df_train.describe().transpose()
train_stats
# Out:
#               count         mean         std     min     25%     50%     75%  \
# MPG           313.0    23.404153    7.666909     9.0    17.5    23.0    29.0
# Cylinders     313.0     5.402556    1.701506     3.0     4.0     4.0     8.0
# Displacement  313.0   189.512780  102.675646    68.0   104.0   140.0   260.0
# Horsepower    313.0   102.929712   37.919046    46.0    75.0    92.0   120.0
# Weight        313.0  2961.198083  848.602146  1613.0  2219.0  2755.0  3574.0
# Acceleration  313.0    15.704473    2.725399     8.5    14.0    15.5    17.3
# ModelYear     313.0    75.929712    3.675305    70.0    73.0    76.0    79.0
# Origin        313.0     1.591054    0.807923     1.0     1.0     1.0     2.0
#
#                  max
# MPG             46.6
# Cylinders        8.0
# Displacement   455.0
# Horsepower     230.0
# Weight        5140.0
# Acceleration    24.8
# ModelYear       82.0
# Origin           3.0

# %%
numeric_column_names = ['Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration']

df_train_norm, df_test_norm = df_train.copy(), df_test.copy()

for col_name in numeric_column_names:
    mean = train_stats.loc[col_name, 'mean']
    std  = train_stats.loc[col_name, 'std']
    df_train_norm.loc[:, col_name] = (df_train_norm.loc[:, col_name] - mean)/std
    df_test_norm.loc[:, col_name] = (df_test_norm.loc[:, col_name] - mean)/std
    
df_train_norm.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower    Weight  Acceleration  \
# 203  28.0  -0.824303     -0.901020   -0.736562 -0.950031      0.255202
# 255  19.4   0.351127      0.413800   -0.340982  0.293190      0.548737
# 72   13.0   1.526556      1.144256    0.713897  1.339617     -0.625403
# 235  30.5  -0.824303     -0.891280   -1.053025 -1.072585      0.475353
# 37   14.0   1.526556      1.563051    1.636916  1.470420     -1.359240
#
#      ModelYear  Origin
# 203         76       3
# 255         78       1
# 72          72       1
# 235         77       1
# 37          71       1

# %% [markdown]
# 앞의 코드에서 만든 판다스의 `DataFrame`은 `float` 타입의 열이 다섯 개 있다. 이 열들은 연속적인 특성으로 구성될 것이다.
# 다음 코드에서 텐서플로의 `feature_column` 함수를 사용하여 이 연속적인 특성을 텐서플로의 추정기가 다룰 수 있는 특성 열 데이터 구조로 변환한다.

# %%
numeric_features = []

for col_name in numeric_column_names:
    numeric_features.append(tf.feature_column.numeric_column(key=col_name))
    
numeric_features
# Out:
# [NumericColumn(key='Cylinders', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Displacement', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Horsepower', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Weight', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='Acceleration', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# 그다음 훈련 모델의 학습 작업을 단순화하기 위해 `model year` 정보를 그룹으로 묶어 버킷(bucket)으로 나눈다.
# 구체적으로 말해서 다음과 같이 각 자동차를 네 개 중 한개의 'year' 버킷에 할당한다.
# $$버킷 = \begin{cases}0 & year < 73 일\, 때 \\
#                      1 & 73 \le year \le 76 일\, 때\\
#                      2 & 76 \le year \le 79 일\, 때\\
#                      3 & year \ge 79 일\, 때
#                      \end{cases}$$
#
# 이 간격은 버킷 개념을 설명하기 위해 임의로 선택한 것이다. 자동차를 세 개의 버킷으로 그룹짓기 위해 먼저 원본 `model year`를 기반으로 수치 특성을 정의한다. 그다음 이 수치 특성을 `[73, 76, 79]` 세 개의 분할 기준을 정한 bucketized_column 함수에 전달한다. 이 값은 분할의 오른쪽 기준이다.

# %%
feature_year = tf.feature_column.numeric_column(key="ModelYear")

bucketized_features = []

bucketized_features.append(tf.feature_column.bucketized_column(
    source_column=feature_year,
    boundaries=[73, 76, 79]))

print(bucketized_features)
# Out:
# [BucketizedColumn(source_column=NumericColumn(key='ModelYear', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(73, 76, 79))]

# %% [markdown]
# 버킷으로 나눈 이 특성 열이 하나이지만 수치 특성과 마찬가지로 동일하게 파이썬 리스트에 추가한다. 다음 단계에서 이 리스트를 다른 특성으로 만든 리스트와 합친다. 이를 텐서플로의 추정기 기반 모델에 입력으로 제공한다.
#
# 그 다음 순서가 없는 범주 특성 `Origin`을 위해 리스트를 정의한다. 텐서플로에는 범주 특성 열을 만드는 방법이 여러 가지 있다. 데이터가 범주 이름(예를 들어 "US", "Europe", "Japan"과 같이 문자열 포맷)이라면 `tf.feature_column.categorical_column_with_vocabulary_list`를 사용하여 가능한 고유 범주 이름을 입력으로 제공할 수 있다.
# 전형적인 텍스트 분석의 경우처럼 가능한 범주 리스트가 너무 크다면 대신 `tf.feature_column.categorical_column_with_vocabulary_file`을 사용할 수 있다. 이 함수를 사용할 때 모든 범주/단어가 들어 있는 파일을 제공하므로 메모리에 모든 가능한 단어 목록을 유지할 필요가 없다. 또한, 특성이 [0, num_categories) 범위의 범주 인덱스에 이미 매핑되어 있다면 `tf.feature_column.categorical_column_with_identity` 함수를 사용할 수 있다. 하지만 여기서는 특성 Origin이 정수 1, 2, 3으로 주어지기 때문에 범주 인덱스가 맞지 않다. 인덱스는 0부터 시작해야 하기 때문이다.

# %%
feature_origin = tf.feature_column.categorical_column_with_vocabulary_list(
    key='Origin',
    vocabulary_list=[1, 2, 3])

# %% [markdown]
# DNNClassifier와 DNNRegressor 같은 추정기는 소위 밀집 열(dense column)만 받는다. 따라서 다음 단계는 이 범주 특성 열을 밀집 열로 바꾸는 것이다.
# 두 가지 방법이 있다. `embedding_column` 함수를 사용하여 임베딩 열로 바꾸거나 `indicator_column` 함수로 인디케이터 열로 바꾸는 것이다.
# 예를 들어 인덱스 0은 [1, 0, 0]으로 인코딩 되고, 인덱스 1은 [0, 1, 0]으로 인코딩되는 식이다.
# 반면 임베딩 열을 각 인덱스를 float 타입의 랜덤한 수치 벡터로 매핑한다.
#
# 범주 개수가 많을 때는 범주 개수보다 적은 차원의 임베딩 열을 사용하여 성능을 높일 수 있다.

# %%
categorical_indicator_features = []
categorical_indicator_features.append(tf.feature_column.indicator_column(feature_origin))

print(categorical_indicator_features)
# Out:
# [IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='Origin', vocabulary_list=(1, 2, 3), dtype=tf.int64, default_value=-1, num_oov_buckets=0))]

# %% [markdown]
# ## 사전에 준비된 추정기로 머신 러닝 수행

# %% [markdown]
# 필수적인 특성 열을 구성한 후 텐서플로 추정기를 사용할 수 있다. 사전 준비된 추정기를 사용하는 단계는 네 가지로 요약할 수 있다.
# 1. 데이터 로드를 위해 입력 함수를 정의한다.
# 2. 데이터셋을 특성 열로 변환한다.
# 3. 추정기 객체를 만든다(사전 준비된 추정기를 사용하거나 케라스 모델을 추정기로 변환하여 새로 만든다).
# 4. 추정기의 train(), evaluate(), predict() 메서드를 사용한다.

# %%
def train_input_fn(df_train, batch_size=8):
    df = df_train.copy()
    train_x, train_y = df, df.pop('MPG')
    dataset = tf.data.Dataset.from_tensor_slices((dict(train_x), train_y))

    # 셔플, 반복, 배치
    return dataset.shuffle(1000).repeat().batch(batch_size)

## 조사
ds = train_input_fn(df_train_norm)
batch = next(iter(ds))
print('키:', batch[0].keys())
print('ModelYear:', batch[0]['ModelYear'])
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# 키: dict_keys(['Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'ModelYear', 'Origin'])
# ModelYear: tf.Tensor([82 78 76 72 78 73 70 78], shape=(8,), dtype=int64)
# 2022-11-23 12:18:48.240911: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-23 12:18:48.241028: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# 이 함수에서 `dict(train_x)`로 판다스 DataFrame 객체를 파이썬 딕셔너리로 바꾸었다.
#
# 모델을 훈련하고 나서 평가할 때 사용할 테스트 데이터셋을 위해서도 입력 함수를 정의해야 한다.

# %%
def eval_input_fn(df_test, batch_size=8):
    df = df_test.copy()
    test_x, test_y = df, df.pop('MPG')
    dataset = tf.data.Dataset.from_tensor_slices((dict(test_x), test_y))

    return dataset.batch(batch_size)

# %% [markdown]
# 두 번째 단계로 넘어가서 특성 열을 정의한다. 연속적인 특성을 담은 리스트, 버킷으로 나눈 특성 열을 위한 리스트, 범주 특성 열을 위한 리스트를 이미 만들어 놓았다.
# 이런 개별 리스트를 연결하여 모든 특성 열을 담은 리스트를 만든다.

# %%
all_feature_columns = (numeric_features + 
                       bucketized_features + 
                       categorical_indicator_features)

print(all_feature_columns)
# Out:
# [NumericColumn(key='Cylinders', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='Displacement', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='Horsepower', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='Weight', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='Acceleration', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), BucketizedColumn(source_column=NumericColumn(key='ModelYear', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(73, 76, 79)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='Origin', vocabulary_list=(1, 2, 3), dtype=tf.int64, default_value=-1, num_oov_buckets=0))]

# %% [markdown]
# 세 번째 단계에서 추정기 객체를 만든다. MPG 값을 예측하는 것은 전형적인 회귀 문제이므로 `tf.estimator.DNNRegressor`를 사용한다.
# 회귀 추정기를 만들 때 특성 열의 리스트와 은닉층의 은닉 유닛 개수를 `hidden_units` 매게변수에 지정해야 한다. 여기서는 두 개의 은닉층을 사용한다.

# %%
regressor = tf.estimator.DNNRegressor(
    feature_columns=all_feature_columns,
    hidden_units=[32, 10], # 첫 번째 은닉층은 32개의 유닛, 두 번째 은닉층은 10개의 유닛을 가진다.
    model_dir='models/autompg-dnnregressor/')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'models/autompg-dnnregressor/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# 또 `model_dir` 매개변수에 모델 파라미터가 저장된 디렉터리를 지정한다. 추정기의 장점 중 하나는 훈련하는 동안 자동으로 모델의 체크포인트 파일을 저장하는 것이다. 따라서 예기치 않은 이유로 모델 훈련이 중지되었을 때 마지막으로 저장된 체크포인트를 로드하여 훈련을 이어갈 수 있다.
# 체크포인트 파일은 `model_dir` 매개변수로 지정된 디렉터리에 저장된다. `model_dir` 매개변수를 지정하지 않았다면 추정기가 랜덤한 임시 폴더를 만들어 체크포인트를 저장한다.
#
# 세 개의 기본 단계를 끝내야 비로소 추정기를 사용하여 훈련, 평가, 예측을 수행할 수 있다.

# %%
EPOCHS = 1000
BATCH_SIZE = 8
total_steps = EPOCHS * int(np.ceil(len(df_train) / BATCH_SIZE))
print('훈련 스텝:', total_steps)

regressor.train(
    input_fn=lambda:train_input_fn(df_train_norm, batch_size=BATCH_SIZE),
    steps=total_steps)
# Out:
# 훈련 스텝: 40000
# WARNING:tensorflow:From /Users/hanhyeongu/miniforge3/envs/hg/lib/python3.8/site-packages/tensorflow/python/training/training_util.py:235: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /Users/hanhyeongu/miniforge3/envs/hg/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/adagrad.py:87: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2022-11-23 12:18:48.921692: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-23 12:18:48.921708: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-11-23 12:18:48.929558: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-11-23 12:18:48.929823: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:18:48.941386: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:18:48.948331: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:18:48.953164: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:18:48.959607: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into models/autompg-dnnregressor/model.ckpt.
# 2022-11-23 12:18:49.425779: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 660.3955, step = 0
# 2022-11-23 12:18:49.825772: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:18:49.833365: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:18:50.017302: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:global_step/sec: 80.7978
# INFO:tensorflow:loss = 513.2289, step = 100 (1.238 sec)
# INFO:tensorflow:global_step/sec: 87.6665
# INFO:tensorflow:loss = 536.07684, step = 200 (1.140 sec)
# INFO:tensorflow:global_step/sec: 106.385
# INFO:tensorflow:loss = 593.9197, step = 300 (0.940 sec)
# INFO:tensorflow:global_step/sec: 107.279
# INFO:tensorflow:loss = 605.18805, step = 400 (0.932 sec)
# INFO:tensorflow:global_step/sec: 106.899
# INFO:tensorflow:loss = 875.4829, step = 500 (0.935 sec)
# INFO:tensorflow:global_step/sec: 105.221
# INFO:tensorflow:loss = 742.5132, step = 600 (0.950 sec)
# INFO:tensorflow:global_step/sec: 101.35
# INFO:tensorflow:loss = 460.9865, step = 700 (0.987 sec)
# INFO:tensorflow:global_step/sec: 101.447
# INFO:tensorflow:loss = 398.84558, step = 800 (0.986 sec)
# INFO:tensorflow:global_step/sec: 105.762
# INFO:tensorflow:loss = 545.3564, step = 900 (0.946 sec)
# INFO:tensorflow:global_step/sec: 101.499
# INFO:tensorflow:loss = 680.369, step = 1000 (0.985 sec)
# INFO:tensorflow:global_step/sec: 103.195
# INFO:tensorflow:loss = 603.0875, step = 1100 (0.969 sec)
# INFO:tensorflow:global_step/sec: 98.4753
# INFO:tensorflow:loss = 689.4984, step = 1200 (1.015 sec)
# INFO:tensorflow:global_step/sec: 96.2674
# INFO:tensorflow:loss = 507.52118, step = 1300 (1.039 sec)
# INFO:tensorflow:global_step/sec: 101.497
# INFO:tensorflow:loss = 724.6218, step = 1400 (0.985 sec)
# INFO:tensorflow:global_step/sec: 103.872
# INFO:tensorflow:loss = 613.48804, step = 1500 (0.963 sec)
# INFO:tensorflow:global_step/sec: 104.636
# INFO:tensorflow:loss = 318.54034, step = 1600 (0.956 sec)
# INFO:tensorflow:global_step/sec: 105.043
# INFO:tensorflow:loss = 538.12634, step = 1700 (0.952 sec)
# INFO:tensorflow:global_step/sec: 104.793
# INFO:tensorflow:loss = 616.21436, step = 1800 (0.954 sec)
# INFO:tensorflow:global_step/sec: 103.692
# INFO:tensorflow:loss = 594.3643, step = 1900 (0.964 sec)
# INFO:tensorflow:global_step/sec: 104.096
# INFO:tensorflow:loss = 419.34296, step = 2000 (0.961 sec)
# INFO:tensorflow:global_step/sec: 106.588
# INFO:tensorflow:loss = 601.68115, step = 2100 (0.938 sec)
# INFO:tensorflow:global_step/sec: 106.637
# INFO:tensorflow:loss = 387.87482, step = 2200 (0.938 sec)
# INFO:tensorflow:global_step/sec: 108.893
# INFO:tensorflow:loss = 424.23822, step = 2300 (0.919 sec)
# INFO:tensorflow:global_step/sec: 107.838
# INFO:tensorflow:loss = 409.20203, step = 2400 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.251
# INFO:tensorflow:loss = 852.006, step = 2500 (0.924 sec)
# INFO:tensorflow:global_step/sec: 109.516
# INFO:tensorflow:loss = 279.3083, step = 2600 (0.913 sec)
# INFO:tensorflow:global_step/sec: 109.681
# INFO:tensorflow:loss = 541.61115, step = 2700 (0.912 sec)
# INFO:tensorflow:global_step/sec: 108.764
# INFO:tensorflow:loss = 427.7966, step = 2800 (0.919 sec)
# INFO:tensorflow:global_step/sec: 109.457
# INFO:tensorflow:loss = 462.14093, step = 2900 (0.914 sec)
# INFO:tensorflow:global_step/sec: 109.949
# INFO:tensorflow:loss = 568.76013, step = 3000 (0.910 sec)
# INFO:tensorflow:global_step/sec: 109.172
# INFO:tensorflow:loss = 441.93097, step = 3100 (0.916 sec)
# INFO:tensorflow:global_step/sec: 106.781
# INFO:tensorflow:loss = 626.52686, step = 3200 (0.937 sec)
# INFO:tensorflow:global_step/sec: 101.008
# INFO:tensorflow:loss = 311.25293, step = 3300 (0.990 sec)
# INFO:tensorflow:global_step/sec: 104.642
# INFO:tensorflow:loss = 307.04755, step = 3400 (0.956 sec)
# INFO:tensorflow:global_step/sec: 104.479
# INFO:tensorflow:loss = 522.9667, step = 3500 (0.957 sec)
# INFO:tensorflow:global_step/sec: 100.555
# INFO:tensorflow:loss = 391.75598, step = 3600 (0.995 sec)
# INFO:tensorflow:global_step/sec: 101.853
# INFO:tensorflow:loss = 302.9458, step = 3700 (0.982 sec)
# INFO:tensorflow:global_step/sec: 106.991
# INFO:tensorflow:loss = 580.487, step = 3800 (0.935 sec)
# INFO:tensorflow:global_step/sec: 103.385
# INFO:tensorflow:loss = 494.87354, step = 3900 (0.967 sec)
# INFO:tensorflow:global_step/sec: 105.457
# INFO:tensorflow:loss = 320.4011, step = 4000 (0.948 sec)
# INFO:tensorflow:global_step/sec: 106.446
# INFO:tensorflow:loss = 289.79327, step = 4100 (0.939 sec)
# INFO:tensorflow:global_step/sec: 102.877
# INFO:tensorflow:loss = 260.15497, step = 4200 (0.972 sec)
# INFO:tensorflow:global_step/sec: 107.097
# INFO:tensorflow:loss = 255.2639, step = 4300 (0.934 sec)
# INFO:tensorflow:global_step/sec: 104.406
# INFO:tensorflow:loss = 518.3864, step = 4400 (0.958 sec)
# INFO:tensorflow:global_step/sec: 103.321
# INFO:tensorflow:loss = 288.4527, step = 4500 (0.968 sec)
# INFO:tensorflow:global_step/sec: 105.523
# INFO:tensorflow:loss = 421.02698, step = 4600 (0.948 sec)
# INFO:tensorflow:global_step/sec: 107.414
# INFO:tensorflow:loss = 325.76794, step = 4700 (0.931 sec)
# INFO:tensorflow:global_step/sec: 107.15
# INFO:tensorflow:loss = 626.5698, step = 4800 (0.933 sec)
# INFO:tensorflow:global_step/sec: 107.346
# INFO:tensorflow:loss = 241.59048, step = 4900 (0.932 sec)
# INFO:tensorflow:global_step/sec: 107.589
# INFO:tensorflow:loss = 365.07745, step = 5000 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.505
# INFO:tensorflow:loss = 143.00224, step = 5100 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.635
# INFO:tensorflow:loss = 417.62918, step = 5200 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.454
# INFO:tensorflow:loss = 172.4819, step = 5300 (0.931 sec)
# INFO:tensorflow:global_step/sec: 108.071
# INFO:tensorflow:loss = 320.94116, step = 5400 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.551
# INFO:tensorflow:loss = 269.47342, step = 5500 (0.921 sec)
# INFO:tensorflow:global_step/sec: 107.793
# INFO:tensorflow:loss = 535.61084, step = 5600 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.487
# INFO:tensorflow:loss = 501.2697, step = 5700 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.862
# INFO:tensorflow:loss = 312.11, step = 5800 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.549
# INFO:tensorflow:loss = 190.0766, step = 5900 (0.921 sec)
# INFO:tensorflow:global_step/sec: 108.047
# INFO:tensorflow:loss = 276.04672, step = 6000 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.707
# INFO:tensorflow:loss = 334.12146, step = 6100 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.493
# INFO:tensorflow:loss = 224.89697, step = 6200 (0.922 sec)
# INFO:tensorflow:global_step/sec: 107.943
# INFO:tensorflow:loss = 250.81929, step = 6300 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.988
# INFO:tensorflow:loss = 113.48632, step = 6400 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.967
# INFO:tensorflow:loss = 263.2943, step = 6500 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.798
# INFO:tensorflow:loss = 170.4236, step = 6600 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.06
# INFO:tensorflow:loss = 168.2373, step = 6700 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.667
# INFO:tensorflow:loss = 155.37767, step = 6800 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.738
# INFO:tensorflow:loss = 266.53595, step = 6900 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.75
# INFO:tensorflow:loss = 253.34207, step = 7000 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.58
# INFO:tensorflow:loss = 219.14095, step = 7100 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.937
# INFO:tensorflow:loss = 321.40027, step = 7200 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.474
# INFO:tensorflow:loss = 300.02344, step = 7300 (0.931 sec)
# INFO:tensorflow:global_step/sec: 107.319
# INFO:tensorflow:loss = 186.5965, step = 7400 (0.932 sec)
# INFO:tensorflow:global_step/sec: 106.727
# INFO:tensorflow:loss = 174.03215, step = 7500 (0.937 sec)
# INFO:tensorflow:global_step/sec: 106.949
# INFO:tensorflow:loss = 236.89772, step = 7600 (0.935 sec)
# INFO:tensorflow:global_step/sec: 107.951
# INFO:tensorflow:loss = 89.19158, step = 7700 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.767
# INFO:tensorflow:loss = 173.31833, step = 7800 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.982
# INFO:tensorflow:loss = 95.414986, step = 7900 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.081
# INFO:tensorflow:loss = 247.74832, step = 8000 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.424
# INFO:tensorflow:loss = 215.38614, step = 8100 (0.931 sec)
# INFO:tensorflow:global_step/sec: 108.222
# INFO:tensorflow:loss = 181.59503, step = 8200 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.087
# INFO:tensorflow:loss = 141.28812, step = 8300 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.447
# INFO:tensorflow:loss = 174.01027, step = 8400 (0.931 sec)
# INFO:tensorflow:global_step/sec: 107.995
# INFO:tensorflow:loss = 114.3678, step = 8500 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.618
# INFO:tensorflow:loss = 135.03098, step = 8600 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.121
# INFO:tensorflow:loss = 139.67896, step = 8700 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.492
# INFO:tensorflow:loss = 142.69698, step = 8800 (0.922 sec)
# INFO:tensorflow:global_step/sec: 107.319
# INFO:tensorflow:loss = 268.2527, step = 8900 (0.932 sec)
# INFO:tensorflow:global_step/sec: 106.39
# INFO:tensorflow:loss = 125.76453, step = 9000 (0.940 sec)
# INFO:tensorflow:global_step/sec: 108.013
# INFO:tensorflow:loss = 162.86534, step = 9100 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.172
# INFO:tensorflow:loss = 214.38976, step = 9200 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.192
# INFO:tensorflow:loss = 91.89081, step = 9300 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.278
# INFO:tensorflow:loss = 132.30283, step = 9400 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.014
# INFO:tensorflow:loss = 94.43739, step = 9500 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.814
# INFO:tensorflow:loss = 140.10902, step = 9600 (0.919 sec)
# INFO:tensorflow:global_step/sec: 108.08
# INFO:tensorflow:loss = 127.07504, step = 9700 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.145
# INFO:tensorflow:loss = 172.25671, step = 9800 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.082
# INFO:tensorflow:loss = 91.12933, step = 9900 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.068
# INFO:tensorflow:loss = 130.6615, step = 10000 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.24
# INFO:tensorflow:loss = 136.63477, step = 10100 (0.924 sec)
# INFO:tensorflow:global_step/sec: 107.862
# INFO:tensorflow:loss = 41.88886, step = 10200 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.366
# INFO:tensorflow:loss = 65.20822, step = 10300 (0.931 sec)
# INFO:tensorflow:global_step/sec: 108.281
# INFO:tensorflow:loss = 99.71053, step = 10400 (0.923 sec)
# INFO:tensorflow:global_step/sec: 107.779
# INFO:tensorflow:loss = 131.5906, step = 10500 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.918
# INFO:tensorflow:loss = 95.45707, step = 10600 (0.927 sec)
# INFO:tensorflow:global_step/sec: 106.892
# INFO:tensorflow:loss = 125.30335, step = 10700 (0.935 sec)
# INFO:tensorflow:global_step/sec: 107.833
# INFO:tensorflow:loss = 40.795372, step = 10800 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.747
# INFO:tensorflow:loss = 90.71753, step = 10900 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.726
# INFO:tensorflow:loss = 105.596886, step = 11000 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.883
# INFO:tensorflow:loss = 99.106346, step = 11100 (0.918 sec)
# INFO:tensorflow:global_step/sec: 108.198
# INFO:tensorflow:loss = 82.32657, step = 11200 (0.924 sec)
# INFO:tensorflow:global_step/sec: 107.657
# INFO:tensorflow:loss = 146.62857, step = 11300 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.351
# INFO:tensorflow:loss = 55.49268, step = 11400 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.477
# INFO:tensorflow:loss = 57.004242, step = 11500 (0.922 sec)
# INFO:tensorflow:global_step/sec: 108.176
# INFO:tensorflow:loss = 127.25336, step = 11600 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.11
# INFO:tensorflow:loss = 15.260848, step = 11700 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.453
# INFO:tensorflow:loss = 94.263176, step = 11800 (0.931 sec)
# INFO:tensorflow:global_step/sec: 108.046
# INFO:tensorflow:loss = 54.06031, step = 11900 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.365
# INFO:tensorflow:loss = 57.866463, step = 12000 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.632
# INFO:tensorflow:loss = 41.321114, step = 12100 (0.921 sec)
# INFO:tensorflow:global_step/sec: 107.598
# INFO:tensorflow:loss = 28.594576, step = 12200 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.052
# INFO:tensorflow:loss = 59.140835, step = 12300 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.811
# INFO:tensorflow:loss = 112.406906, step = 12400 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.764
# INFO:tensorflow:loss = 44.347515, step = 12500 (0.919 sec)
# INFO:tensorflow:global_step/sec: 108.451
# INFO:tensorflow:loss = 48.849586, step = 12600 (0.922 sec)
# INFO:tensorflow:global_step/sec: 107.872
# INFO:tensorflow:loss = 56.75305, step = 12700 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.999
# INFO:tensorflow:loss = 95.05022, step = 12800 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.064
# INFO:tensorflow:loss = 91.68451, step = 12900 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.276
# INFO:tensorflow:loss = 35.466743, step = 13000 (0.932 sec)
# INFO:tensorflow:global_step/sec: 107.728
# INFO:tensorflow:loss = 60.331047, step = 13100 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.977
# INFO:tensorflow:loss = 25.024687, step = 13200 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.543
# INFO:tensorflow:loss = 18.467781, step = 13300 (0.921 sec)
# INFO:tensorflow:global_step/sec: 107.72
# INFO:tensorflow:loss = 98.41832, step = 13400 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.462
# INFO:tensorflow:loss = 21.702686, step = 13500 (0.922 sec)
# INFO:tensorflow:global_step/sec: 107.112
# INFO:tensorflow:loss = 67.23808, step = 13600 (0.934 sec)
# INFO:tensorflow:global_step/sec: 107.623
# INFO:tensorflow:loss = 34.6097, step = 13700 (0.929 sec)
# INFO:tensorflow:global_step/sec: 106.935
# INFO:tensorflow:loss = 57.664963, step = 13800 (0.935 sec)
# INFO:tensorflow:global_step/sec: 108.059
# INFO:tensorflow:loss = 50.993187, step = 13900 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.781
# INFO:tensorflow:loss = 35.42677, step = 14000 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.104
# INFO:tensorflow:loss = 37.662037, step = 14100 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.108
# INFO:tensorflow:loss = 57.352024, step = 14200 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.282
# INFO:tensorflow:loss = 41.950897, step = 14300 (0.932 sec)
# INFO:tensorflow:global_step/sec: 106.768
# INFO:tensorflow:loss = 39.201324, step = 14400 (0.936 sec)
# INFO:tensorflow:global_step/sec: 107.26
# INFO:tensorflow:loss = 19.348465, step = 14500 (0.932 sec)
# INFO:tensorflow:global_step/sec: 107.814
# INFO:tensorflow:loss = 67.01891, step = 14600 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.059
# INFO:tensorflow:loss = 23.829504, step = 14700 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.275
# INFO:tensorflow:loss = 61.81255, step = 14800 (0.924 sec)
# INFO:tensorflow:global_step/sec: 107.583
# INFO:tensorflow:loss = 49.8397, step = 14900 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.98
# INFO:tensorflow:loss = 23.283518, step = 15000 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.854
# INFO:tensorflow:loss = 26.961908, step = 15100 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.73
# INFO:tensorflow:loss = 38.09085, step = 15200 (0.920 sec)
# INFO:tensorflow:global_step/sec: 108.027
# INFO:tensorflow:loss = 20.866158, step = 15300 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.138
# INFO:tensorflow:loss = 17.396717, step = 15400 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.16
# INFO:tensorflow:loss = 54.003426, step = 15500 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.732
# INFO:tensorflow:loss = 22.552248, step = 15600 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.247
# INFO:tensorflow:loss = 10.302706, step = 15700 (0.924 sec)
# INFO:tensorflow:global_step/sec: 107.96
# INFO:tensorflow:loss = 19.773315, step = 15800 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.807
# INFO:tensorflow:loss = 33.44229, step = 15900 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.169
# INFO:tensorflow:loss = 23.361664, step = 16000 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.558
# INFO:tensorflow:loss = 66.35171, step = 16100 (0.930 sec)
# INFO:tensorflow:global_step/sec: 108.221
# INFO:tensorflow:loss = 32.427017, step = 16200 (0.924 sec)
# INFO:tensorflow:global_step/sec: 107.998
# INFO:tensorflow:loss = 13.260578, step = 16300 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.458
# INFO:tensorflow:loss = 34.7481, step = 16400 (0.922 sec)
# INFO:tensorflow:global_step/sec: 107.796
# INFO:tensorflow:loss = 37.186848, step = 16500 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.407
# INFO:tensorflow:loss = 9.960653, step = 16600 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.347
# INFO:tensorflow:loss = 11.650581, step = 16700 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.094
# INFO:tensorflow:loss = 56.272522, step = 16800 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.141
# INFO:tensorflow:loss = 24.083405, step = 16900 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.52
# INFO:tensorflow:loss = 21.46417, step = 17000 (0.921 sec)
# INFO:tensorflow:global_step/sec: 108.144
# INFO:tensorflow:loss = 19.505796, step = 17100 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.173
# INFO:tensorflow:loss = 11.739153, step = 17200 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.436
# INFO:tensorflow:loss = 27.821445, step = 17300 (0.922 sec)
# INFO:tensorflow:global_step/sec: 107.522
# INFO:tensorflow:loss = 14.923185, step = 17400 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.96
# INFO:tensorflow:loss = 21.960987, step = 17500 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.888
# INFO:tensorflow:loss = 51.750034, step = 17600 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.92
# INFO:tensorflow:loss = 16.915201, step = 17700 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.713
# INFO:tensorflow:loss = 7.4781966, step = 17800 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.283
# INFO:tensorflow:loss = 6.369874, step = 17900 (0.932 sec)
# INFO:tensorflow:global_step/sec: 107.528
# INFO:tensorflow:loss = 30.377258, step = 18000 (0.930 sec)
# INFO:tensorflow:global_step/sec: 108.121
# INFO:tensorflow:loss = 9.102639, step = 18100 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.37
# INFO:tensorflow:loss = 11.107832, step = 18200 (0.931 sec)
# INFO:tensorflow:global_step/sec: 107.904
# INFO:tensorflow:loss = 11.403524, step = 18300 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.379
# INFO:tensorflow:loss = 27.456627, step = 18400 (0.923 sec)
# INFO:tensorflow:global_step/sec: 107.621
# INFO:tensorflow:loss = 14.904055, step = 18500 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.73
# INFO:tensorflow:loss = 34.91446, step = 18600 (0.920 sec)
# INFO:tensorflow:global_step/sec: 108.406
# INFO:tensorflow:loss = 33.87301, step = 18700 (0.923 sec)
# INFO:tensorflow:global_step/sec: 107.357
# INFO:tensorflow:loss = 26.799107, step = 18800 (0.931 sec)
# INFO:tensorflow:global_step/sec: 108.249
# INFO:tensorflow:loss = 11.235482, step = 18900 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.307
# INFO:tensorflow:loss = 37.023773, step = 19000 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.19
# INFO:tensorflow:loss = 11.086172, step = 19100 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.256
# INFO:tensorflow:loss = 41.525795, step = 19200 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.024
# INFO:tensorflow:loss = 20.566708, step = 19300 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.777
# INFO:tensorflow:loss = 16.55676, step = 19400 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.297
# INFO:tensorflow:loss = 18.824854, step = 19500 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.789
# INFO:tensorflow:loss = 12.021665, step = 19600 (0.919 sec)
# INFO:tensorflow:global_step/sec: 106.594
# INFO:tensorflow:loss = 22.114992, step = 19700 (0.938 sec)
# INFO:tensorflow:global_step/sec: 108.518
# INFO:tensorflow:loss = 27.180641, step = 19800 (0.921 sec)
# INFO:tensorflow:global_step/sec: 108.966
# INFO:tensorflow:loss = 19.03219, step = 19900 (0.918 sec)
# INFO:tensorflow:global_step/sec: 107.12
# INFO:tensorflow:loss = 18.012154, step = 20000 (0.934 sec)
# INFO:tensorflow:global_step/sec: 106.225
# INFO:tensorflow:loss = 19.199543, step = 20100 (0.941 sec)
# INFO:tensorflow:global_step/sec: 107.905
# INFO:tensorflow:loss = 33.747154, step = 20200 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.358
# INFO:tensorflow:loss = 12.20252, step = 20300 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.04
# INFO:tensorflow:loss = 6.1693306, step = 20400 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.171
# INFO:tensorflow:loss = 6.457231, step = 20500 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.86
# INFO:tensorflow:loss = 24.075153, step = 20600 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.966
# INFO:tensorflow:loss = 8.402381, step = 20700 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.584
# INFO:tensorflow:loss = 16.73044, step = 20800 (0.921 sec)
# INFO:tensorflow:global_step/sec: 108.03
# INFO:tensorflow:loss = 10.631033, step = 20900 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.133
# INFO:tensorflow:loss = 15.907955, step = 21000 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.074
# INFO:tensorflow:loss = 25.622164, step = 21100 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.873
# INFO:tensorflow:loss = 12.598835, step = 21200 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.285
# INFO:tensorflow:loss = 15.17525, step = 21300 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.006
# INFO:tensorflow:loss = 22.146946, step = 21400 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.098
# INFO:tensorflow:loss = 16.106094, step = 21500 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.302
# INFO:tensorflow:loss = 27.126781, step = 21600 (0.923 sec)
# INFO:tensorflow:global_step/sec: 107.889
# INFO:tensorflow:loss = 42.828854, step = 21700 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.021
# INFO:tensorflow:loss = 36.371193, step = 21800 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.598
# INFO:tensorflow:loss = 23.099241, step = 21900 (0.921 sec)
# INFO:tensorflow:global_step/sec: 108.823
# INFO:tensorflow:loss = 7.5763345, step = 22000 (0.919 sec)
# INFO:tensorflow:global_step/sec: 108.271
# INFO:tensorflow:loss = 3.4432364, step = 22100 (0.924 sec)
# INFO:tensorflow:global_step/sec: 103.496
# INFO:tensorflow:loss = 8.072845, step = 22200 (0.966 sec)
# INFO:tensorflow:global_step/sec: 107.144
# INFO:tensorflow:loss = 7.8367167, step = 22300 (0.933 sec)
# INFO:tensorflow:global_step/sec: 101.867
# INFO:tensorflow:loss = 21.640942, step = 22400 (0.982 sec)
# INFO:tensorflow:global_step/sec: 106.991
# INFO:tensorflow:loss = 3.0533032, step = 22500 (0.935 sec)
# INFO:tensorflow:global_step/sec: 106.69
# INFO:tensorflow:loss = 21.510765, step = 22600 (0.937 sec)
# INFO:tensorflow:global_step/sec: 107.463
# INFO:tensorflow:loss = 54.07646, step = 22700 (0.931 sec)
# INFO:tensorflow:global_step/sec: 107.545
# INFO:tensorflow:loss = 12.361193, step = 22800 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.575
# INFO:tensorflow:loss = 37.28862, step = 22900 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.556
# INFO:tensorflow:loss = 8.244786, step = 23000 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.204
# INFO:tensorflow:loss = 38.67241, step = 23100 (0.933 sec)
# INFO:tensorflow:global_step/sec: 107.435
# INFO:tensorflow:loss = 22.388926, step = 23200 (0.931 sec)
# INFO:tensorflow:global_step/sec: 107.059
# INFO:tensorflow:loss = 18.092735, step = 23300 (0.934 sec)
# INFO:tensorflow:global_step/sec: 107.005
# INFO:tensorflow:loss = 11.488335, step = 23400 (0.934 sec)
# INFO:tensorflow:global_step/sec: 107.71
# INFO:tensorflow:loss = 12.002411, step = 23500 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.604
# INFO:tensorflow:loss = 9.212887, step = 23600 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.608
# INFO:tensorflow:loss = 17.106932, step = 23700 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.052
# INFO:tensorflow:loss = 5.2515187, step = 23800 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.789
# INFO:tensorflow:loss = 16.12469, step = 23900 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.667
# INFO:tensorflow:loss = 57.141624, step = 24000 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.376
# INFO:tensorflow:loss = 11.414223, step = 24100 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.283
# INFO:tensorflow:loss = 10.807898, step = 24200 (0.923 sec)
# INFO:tensorflow:global_step/sec: 107.93
# INFO:tensorflow:loss = 8.517507, step = 24300 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.093
# INFO:tensorflow:loss = 13.970425, step = 24400 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.431
# INFO:tensorflow:loss = 7.3971434, step = 24500 (0.922 sec)
# INFO:tensorflow:global_step/sec: 107.512
# INFO:tensorflow:loss = 30.376068, step = 24600 (0.930 sec)
# INFO:tensorflow:global_step/sec: 108.063
# INFO:tensorflow:loss = 37.94394, step = 24700 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.221
# INFO:tensorflow:loss = 38.623608, step = 24800 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.086
# INFO:tensorflow:loss = 4.519219, step = 24900 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.612
# INFO:tensorflow:loss = 7.658859, step = 25000 (0.921 sec)
# INFO:tensorflow:global_step/sec: 107.997
# INFO:tensorflow:loss = 28.193819, step = 25100 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.324
# INFO:tensorflow:loss = 32.308247, step = 25200 (0.923 sec)
# INFO:tensorflow:global_step/sec: 107.398
# INFO:tensorflow:loss = 10.11767, step = 25300 (0.931 sec)
# INFO:tensorflow:global_step/sec: 107.87
# INFO:tensorflow:loss = 10.689713, step = 25400 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.239
# INFO:tensorflow:loss = 3.8479652, step = 25500 (0.932 sec)
# INFO:tensorflow:global_step/sec: 107.643
# INFO:tensorflow:loss = 15.887405, step = 25600 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.941
# INFO:tensorflow:loss = 40.947014, step = 25700 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.366
# INFO:tensorflow:loss = 21.018854, step = 25800 (0.931 sec)
# INFO:tensorflow:global_step/sec: 107.886
# INFO:tensorflow:loss = 22.064999, step = 25900 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.324
# INFO:tensorflow:loss = 22.8326, step = 26000 (0.923 sec)
# INFO:tensorflow:global_step/sec: 107.963
# INFO:tensorflow:loss = 26.15261, step = 26100 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.241
# INFO:tensorflow:loss = 20.217978, step = 26200 (0.932 sec)
# INFO:tensorflow:global_step/sec: 108.32
# INFO:tensorflow:loss = 8.687349, step = 26300 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.138
# INFO:tensorflow:loss = 18.911528, step = 26400 (0.925 sec)
# INFO:tensorflow:global_step/sec: 105.467
# INFO:tensorflow:loss = 26.263597, step = 26500 (0.948 sec)
# INFO:tensorflow:global_step/sec: 106.619
# INFO:tensorflow:loss = 11.358966, step = 26600 (0.938 sec)
# INFO:tensorflow:global_step/sec: 107.737
# INFO:tensorflow:loss = 16.94931, step = 26700 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.856
# INFO:tensorflow:loss = 3.4937456, step = 26800 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.532
# INFO:tensorflow:loss = 19.504902, step = 26900 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.36
# INFO:tensorflow:loss = 3.0757828, step = 27000 (0.932 sec)
# INFO:tensorflow:global_step/sec: 107.218
# INFO:tensorflow:loss = 32.926838, step = 27100 (0.933 sec)
# INFO:tensorflow:global_step/sec: 108.307
# INFO:tensorflow:loss = 14.212091, step = 27200 (0.923 sec)
# INFO:tensorflow:global_step/sec: 106.766
# INFO:tensorflow:loss = 16.155592, step = 27300 (0.937 sec)
# INFO:tensorflow:global_step/sec: 108.23
# INFO:tensorflow:loss = 16.818724, step = 27400 (0.924 sec)
# INFO:tensorflow:global_step/sec: 107.617
# INFO:tensorflow:loss = 8.789261, step = 27500 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.502
# INFO:tensorflow:loss = 16.585732, step = 27600 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.833
# INFO:tensorflow:loss = 19.995008, step = 27700 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.84
# INFO:tensorflow:loss = 13.089937, step = 27800 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.085
# INFO:tensorflow:loss = 44.680695, step = 27900 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.318
# INFO:tensorflow:loss = 26.687561, step = 28000 (0.932 sec)
# INFO:tensorflow:global_step/sec: 108.166
# INFO:tensorflow:loss = 7.5181594, step = 28100 (0.924 sec)
# INFO:tensorflow:global_step/sec: 107.783
# INFO:tensorflow:loss = 14.948469, step = 28200 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.764
# INFO:tensorflow:loss = 4.8370957, step = 28300 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.996
# INFO:tensorflow:loss = 35.82242, step = 28400 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.12
# INFO:tensorflow:loss = 23.665705, step = 28500 (0.934 sec)
# INFO:tensorflow:global_step/sec: 107.526
# INFO:tensorflow:loss = 20.302376, step = 28600 (0.930 sec)
# INFO:tensorflow:global_step/sec: 108.74
# INFO:tensorflow:loss = 10.284225, step = 28700 (0.920 sec)
# INFO:tensorflow:global_step/sec: 107.606
# INFO:tensorflow:loss = 22.549812, step = 28800 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.606
# INFO:tensorflow:loss = 5.252934, step = 28900 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.906
# INFO:tensorflow:loss = 27.01305, step = 29000 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.785
# INFO:tensorflow:loss = 30.227886, step = 29100 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.665
# INFO:tensorflow:loss = 8.028944, step = 29200 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.594
# INFO:tensorflow:loss = 15.947958, step = 29300 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.789
# INFO:tensorflow:loss = 22.236038, step = 29400 (0.919 sec)
# INFO:tensorflow:global_step/sec: 108.24
# INFO:tensorflow:loss = 12.507158, step = 29500 (0.924 sec)
# INFO:tensorflow:global_step/sec: 108.62
# INFO:tensorflow:loss = 9.387904, step = 29600 (0.921 sec)
# INFO:tensorflow:global_step/sec: 107.795
# INFO:tensorflow:loss = 16.890972, step = 29700 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.802
# INFO:tensorflow:loss = 17.84636, step = 29800 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.563
# INFO:tensorflow:loss = 12.041332, step = 29900 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.703
# INFO:tensorflow:loss = 36.924965, step = 30000 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.885
# INFO:tensorflow:loss = 7.093346, step = 30100 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.02
# INFO:tensorflow:loss = 6.01335, step = 30200 (0.926 sec)
# INFO:tensorflow:global_step/sec: 106.915
# INFO:tensorflow:loss = 11.40539, step = 30300 (0.935 sec)
# INFO:tensorflow:global_step/sec: 108.037
# INFO:tensorflow:loss = 7.3411407, step = 30400 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.252
# INFO:tensorflow:loss = 10.446602, step = 30500 (0.932 sec)
# INFO:tensorflow:global_step/sec: 108.122
# INFO:tensorflow:loss = 21.003681, step = 30600 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.457
# INFO:tensorflow:loss = 15.678591, step = 30700 (0.922 sec)
# INFO:tensorflow:global_step/sec: 108.314
# INFO:tensorflow:loss = 17.453547, step = 30800 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.217
# INFO:tensorflow:loss = 15.539375, step = 30900 (0.924 sec)
# INFO:tensorflow:global_step/sec: 107.614
# INFO:tensorflow:loss = 10.293659, step = 31000 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.057
# INFO:tensorflow:loss = 14.789515, step = 31100 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.981
# INFO:tensorflow:loss = 28.05391, step = 31200 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.454
# INFO:tensorflow:loss = 17.62408, step = 31300 (0.922 sec)
# INFO:tensorflow:global_step/sec: 107.973
# INFO:tensorflow:loss = 13.275875, step = 31400 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.52
# INFO:tensorflow:loss = 7.0421543, step = 31500 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.584
# INFO:tensorflow:loss = 14.286344, step = 31600 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.025
# INFO:tensorflow:loss = 6.8229628, step = 31700 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.111
# INFO:tensorflow:loss = 8.204651, step = 31800 (0.925 sec)
# INFO:tensorflow:global_step/sec: 106.681
# INFO:tensorflow:loss = 14.040688, step = 31900 (0.938 sec)
# INFO:tensorflow:global_step/sec: 106.969
# INFO:tensorflow:loss = 3.7639415, step = 32000 (0.935 sec)
# INFO:tensorflow:global_step/sec: 107.824
# INFO:tensorflow:loss = 10.229128, step = 32100 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.516
# INFO:tensorflow:loss = 5.849419, step = 32200 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.739
# INFO:tensorflow:loss = 7.694064, step = 32300 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.058
# INFO:tensorflow:loss = 5.2384324, step = 32400 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.773
# INFO:tensorflow:loss = 6.540655, step = 32500 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.128
# INFO:tensorflow:loss = 6.7250156, step = 32600 (0.925 sec)
# INFO:tensorflow:global_step/sec: 106.251
# INFO:tensorflow:loss = 14.69808, step = 32700 (0.941 sec)
# INFO:tensorflow:global_step/sec: 107.834
# INFO:tensorflow:loss = 9.933865, step = 32800 (0.927 sec)
# INFO:tensorflow:global_step/sec: 107.102
# INFO:tensorflow:loss = 6.4287834, step = 32900 (0.934 sec)
# INFO:tensorflow:global_step/sec: 106.671
# INFO:tensorflow:loss = 8.60446, step = 33000 (0.937 sec)
# INFO:tensorflow:global_step/sec: 107.755
# INFO:tensorflow:loss = 4.627798, step = 33100 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.294
# INFO:tensorflow:loss = 15.845147, step = 33200 (0.924 sec)
# INFO:tensorflow:global_step/sec: 107.385
# INFO:tensorflow:loss = 9.502878, step = 33300 (0.931 sec)
# INFO:tensorflow:global_step/sec: 106.984
# INFO:tensorflow:loss = 18.394014, step = 33400 (0.935 sec)
# INFO:tensorflow:global_step/sec: 107.731
# INFO:tensorflow:loss = 2.7882082, step = 33500 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.293
# INFO:tensorflow:loss = 9.867315, step = 33600 (0.932 sec)
# INFO:tensorflow:global_step/sec: 107.708
# INFO:tensorflow:loss = 40.23375, step = 33700 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.045
# INFO:tensorflow:loss = 4.8175483, step = 33800 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.572
# INFO:tensorflow:loss = 5.1355267, step = 33900 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.736
# INFO:tensorflow:loss = 29.697704, step = 34000 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.057
# INFO:tensorflow:loss = 21.564684, step = 34100 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.394
# INFO:tensorflow:loss = 10.741712, step = 34200 (0.923 sec)
# INFO:tensorflow:global_step/sec: 104.083
# INFO:tensorflow:loss = 12.19159, step = 34300 (0.961 sec)
# INFO:tensorflow:global_step/sec: 101.5
# INFO:tensorflow:loss = 2.4983177, step = 34400 (0.985 sec)
# INFO:tensorflow:global_step/sec: 103.458
# INFO:tensorflow:loss = 21.040026, step = 34500 (0.966 sec)
# INFO:tensorflow:global_step/sec: 100.004
# INFO:tensorflow:loss = 16.24104, step = 34600 (1.000 sec)
# INFO:tensorflow:global_step/sec: 100.444
# INFO:tensorflow:loss = 11.665333, step = 34700 (0.995 sec)
# INFO:tensorflow:global_step/sec: 106.604
# INFO:tensorflow:loss = 12.05216, step = 34800 (0.938 sec)
# INFO:tensorflow:global_step/sec: 109.665
# INFO:tensorflow:loss = 24.614697, step = 34900 (0.912 sec)
# INFO:tensorflow:global_step/sec: 108.596
# INFO:tensorflow:loss = 9.45427, step = 35000 (0.921 sec)
# INFO:tensorflow:global_step/sec: 106.537
# INFO:tensorflow:loss = 4.469965, step = 35100 (0.939 sec)
# INFO:tensorflow:global_step/sec: 107
# INFO:tensorflow:loss = 16.964546, step = 35200 (0.934 sec)
# INFO:tensorflow:global_step/sec: 106.792
# INFO:tensorflow:loss = 6.686345, step = 35300 (0.936 sec)
# INFO:tensorflow:global_step/sec: 107.584
# INFO:tensorflow:loss = 3.2442193, step = 35400 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.706
# INFO:tensorflow:loss = 7.5086255, step = 35500 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.238
# INFO:tensorflow:loss = 8.4353695, step = 35600 (0.932 sec)
# INFO:tensorflow:global_step/sec: 107.732
# INFO:tensorflow:loss = 16.398518, step = 35700 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.716
# INFO:tensorflow:loss = 3.3401442, step = 35800 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.79
# INFO:tensorflow:loss = 19.338036, step = 35900 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.266
# INFO:tensorflow:loss = 9.323636, step = 36000 (0.932 sec)
# INFO:tensorflow:global_step/sec: 107.784
# INFO:tensorflow:loss = 3.8125415, step = 36100 (0.928 sec)
# INFO:tensorflow:global_step/sec: 107.957
# INFO:tensorflow:loss = 15.101694, step = 36200 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.096
# INFO:tensorflow:loss = 31.214958, step = 36300 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.034
# INFO:tensorflow:loss = 13.926631, step = 36400 (0.926 sec)
# INFO:tensorflow:global_step/sec: 108.064
# INFO:tensorflow:loss = 8.349703, step = 36500 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.575
# INFO:tensorflow:loss = 15.182178, step = 36600 (0.930 sec)
# INFO:tensorflow:global_step/sec: 108.123
# INFO:tensorflow:loss = 8.885564, step = 36700 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.998
# INFO:tensorflow:loss = 15.8571825, step = 36800 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.975
# INFO:tensorflow:loss = 7.4169254, step = 36900 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.604
# INFO:tensorflow:loss = 4.2191377, step = 37000 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.097
# INFO:tensorflow:loss = 8.701935, step = 37100 (0.934 sec)
# INFO:tensorflow:global_step/sec: 107.019
# INFO:tensorflow:loss = 29.500828, step = 37200 (0.934 sec)
# INFO:tensorflow:global_step/sec: 108.52
# INFO:tensorflow:loss = 12.983603, step = 37300 (0.922 sec)
# INFO:tensorflow:global_step/sec: 107.294
# INFO:tensorflow:loss = 11.467699, step = 37400 (0.932 sec)
# INFO:tensorflow:global_step/sec: 108.035
# INFO:tensorflow:loss = 11.979934, step = 37500 (0.926 sec)
# INFO:tensorflow:global_step/sec: 107.783
# INFO:tensorflow:loss = 21.646713, step = 37600 (0.928 sec)
# INFO:tensorflow:global_step/sec: 106.235
# INFO:tensorflow:loss = 21.416767, step = 37700 (0.941 sec)
# INFO:tensorflow:global_step/sec: 107.454
# INFO:tensorflow:loss = 17.109463, step = 37800 (0.931 sec)
# INFO:tensorflow:global_step/sec: 107.614
# INFO:tensorflow:loss = 19.774246, step = 37900 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.494
# INFO:tensorflow:loss = 5.0142164, step = 38000 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.032
# INFO:tensorflow:loss = 4.9173183, step = 38100 (0.934 sec)
# INFO:tensorflow:global_step/sec: 107.666
# INFO:tensorflow:loss = 4.784366, step = 38200 (0.929 sec)
# INFO:tensorflow:global_step/sec: 107.533
# INFO:tensorflow:loss = 5.4547944, step = 38300 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.768
# INFO:tensorflow:loss = 8.332249, step = 38400 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.301
# INFO:tensorflow:loss = 3.209691, step = 38500 (0.923 sec)
# INFO:tensorflow:global_step/sec: 106.667
# INFO:tensorflow:loss = 1.8309243, step = 38600 (0.937 sec)
# INFO:tensorflow:global_step/sec: 107.261
# INFO:tensorflow:loss = 29.87894, step = 38700 (0.932 sec)
# INFO:tensorflow:global_step/sec: 107.369
# INFO:tensorflow:loss = 12.100072, step = 38800 (0.931 sec)
# INFO:tensorflow:global_step/sec: 106.92
# INFO:tensorflow:loss = 9.011936, step = 38900 (0.935 sec)
# INFO:tensorflow:global_step/sec: 107.428
# INFO:tensorflow:loss = 13.590827, step = 39000 (0.931 sec)
# INFO:tensorflow:global_step/sec: 107.489
# INFO:tensorflow:loss = 22.867325, step = 39100 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.522
# INFO:tensorflow:loss = 18.664965, step = 39200 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.943
# INFO:tensorflow:loss = 33.80823, step = 39300 (0.926 sec)
# INFO:tensorflow:global_step/sec: 105.828
# INFO:tensorflow:loss = 6.817647, step = 39400 (0.945 sec)
# INFO:tensorflow:global_step/sec: 107.117
# INFO:tensorflow:loss = 13.378731, step = 39500 (0.934 sec)
# INFO:tensorflow:global_step/sec: 107.285
# INFO:tensorflow:loss = 13.681404, step = 39600 (0.932 sec)
# INFO:tensorflow:global_step/sec: 107.524
# INFO:tensorflow:loss = 7.2874327, step = 39700 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.397
# INFO:tensorflow:loss = 5.010824, step = 39800 (0.931 sec)
# INFO:tensorflow:global_step/sec: 107.562
# INFO:tensorflow:loss = 18.659382, step = 39900 (0.930 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 40000...
# INFO:tensorflow:Saving checkpoints for 40000 into models/autompg-dnnregressor/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 40000...
# INFO:tensorflow:Loss for final step: 8.269392.

# %% [markdown]
# `.train()`을 호출하면 자동으로 모델 훈련하는 과정 동안 체크포인트를 저장한다. 나중에 마지막 체크포인트를 다시 불러올 수 있다.

# %%
reloaded_regressor = tf.estimator.DNNRegressor(
    feature_columns=all_feature_columns,
    hidden_units=[32, 10],
    warm_start_from='models/autompg-dnnregressor/',
    model_dir='models/autompg-dnnregressor/')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'models/autompg-dnnregressor/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# 그다음 훈련된 모델의 예측 성능을 평가하기 위해 다음과 같이 `evalueate()` 메서드를 사용할 수 있다.

# %%
eval_results = reloaded_regressor.evaluate(
    input_fn=lambda:eval_input_fn(df_test_norm, batch_size=8))

for key in eval_results:
    print('{:15s} {}'.format(key, eval_results[key]))
    
print('평균 손실 {:.4f}'.format(eval_results['average_loss']))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2022-11-23T12:25:03
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/autompg-dnnregressor/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2022-11-23 12:25:03.508771: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-23 12:25:03.508790: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-11-23 12:25:03.519199: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:03.526443: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:03.532879: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:03.541425: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:03.549611: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:03.555081: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:Inference Time : 0.27546s
# INFO:tensorflow:Finished evaluation at 2022-11-23-12:25:03
# INFO:tensorflow:Saving dict for global step 40000: average_loss = 16.535028, global_step = 40000, label/mean = 23.611393, loss = 16.465263, prediction/mean = 21.969591
# 2022-11-23 12:25:03.736503: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 40000: models/autompg-dnnregressor/model.ckpt-40000
# average_loss    16.5350284576416
# label/mean      23.611392974853516
# loss            16.46526336669922
# prediction/mean 21.96959114074707
# global_step     40000
# 평균 손실 16.5350

# %%
pred_res = regressor.predict(input_fn=lambda: eval_input_fn(df_test_norm, batch_size=8))

print(next(iter(pred_res)))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from models/autompg-dnnregressor/model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'predictions': array([23.059402], dtype=float32)}
# 2022-11-23 12:25:04.274371: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-23 12:25:04.274387: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-11-23 12:25:04.280660: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:04.286104: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:04.292308: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:04.296961: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:04.302365: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:04.307599: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# ### Boosted Tree Regressor

# %%
boosted_tree = tf.estimator.BoostedTreesRegressor(
    feature_columns=all_feature_columns,
    n_batches_per_layer=20,
    n_trees=200)

boosted_tree.train(
    input_fn=lambda:train_input_fn(df_train_norm, batch_size=BATCH_SIZE))

eval_results = boosted_tree.evaluate(
    input_fn=lambda:eval_input_fn(df_test_norm, batch_size=8))

print(eval_results)

print('평균 손실 {:.4f}'.format(eval_results['average_loss']))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/tb/x7hcv5j94gn9b46c7qc1vfth0000gn/T/tmp54lx3zxg
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/tb/x7hcv5j94gn9b46c7qc1vfth0000gn/T/tmp54lx3zxg', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /Users/hanhyeongu/miniforge3/envs/hg/lib/python3.8/site-packages/tensorflow_estimator/python/estimator/canned/boosted_trees.py:398: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# INFO:tensorflow:Calling model_fn.
# Exception ignored in: <function CapturableResource.__del__ at 0x13010b670>
# Traceback (most recent call last):
#   File "/Users/hanhyeongu/miniforge3/envs/hg/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py", line 269, in __del__
#     with self._destruction_context():
# AttributeError: 'TreeEnsemble' object has no attribute '_destruction_context'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2022-11-23 12:25:04.887430: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-23 12:25:04.887450: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-11-23 12:25:04.899680: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:04.906847: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:04.915187: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:04.921194: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:04.929210: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/tb/x7hcv5j94gn9b46c7qc1vfth0000gn/T/tmp54lx3zxg/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# 2022-11-23 12:25:05.448904: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 635.98627, step = 0
# 2022-11-23 12:25:05.716514: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:05.721931: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:05.728413: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:25:05.881221: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 0 vs previous value: 0. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:loss = 310.6216, step = 80 (1.062 sec)
# 2022-11-23 12:25:06.863488: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:global_step/sec: 76.9294
# 2022-11-23 12:25:07.094178: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:loss = 87.98961, step = 180 (0.926 sec)
# INFO:tensorflow:global_step/sec: 117.175
# INFO:tensorflow:loss = 12.477409, step = 280 (0.860 sec)
# INFO:tensorflow:global_step/sec: 116.354
# INFO:tensorflow:loss = 21.24339, step = 380 (0.868 sec)
# INFO:tensorflow:global_step/sec: 115.448
# INFO:tensorflow:loss = 3.383421, step = 480 (0.870 sec)
# INFO:tensorflow:global_step/sec: 114.988
# INFO:tensorflow:loss = 3.462254, step = 580 (0.853 sec)
# INFO:tensorflow:global_step/sec: 115.82
# INFO:tensorflow:loss = 2.5799599, step = 680 (0.858 sec)
# INFO:tensorflow:global_step/sec: 117.031
# INFO:tensorflow:loss = 4.941435, step = 780 (0.867 sec)
# INFO:tensorflow:global_step/sec: 115.713
# INFO:tensorflow:loss = 3.070099, step = 880 (0.868 sec)
# INFO:tensorflow:global_step/sec: 115.54
# INFO:tensorflow:loss = 1.8310149, step = 980 (0.871 sec)
# INFO:tensorflow:global_step/sec: 114.716
# INFO:tensorflow:loss = 1.8351343, step = 1080 (0.862 sec)
# INFO:tensorflow:global_step/sec: 116.207
# INFO:tensorflow:loss = 1.6367164, step = 1180 (0.846 sec)
# INFO:tensorflow:global_step/sec: 116.919
# INFO:tensorflow:loss = 0.83402705, step = 1280 (0.854 sec)
# INFO:tensorflow:global_step/sec: 117.705
# INFO:tensorflow:loss = 4.0222874, step = 1380 (0.860 sec)
# INFO:tensorflow:global_step/sec: 116.767
# INFO:tensorflow:loss = 1.3170781, step = 1480 (0.861 sec)
# INFO:tensorflow:global_step/sec: 116.235
# INFO:tensorflow:loss = 0.8403686, step = 1580 (0.861 sec)
# INFO:tensorflow:global_step/sec: 116.241
# INFO:tensorflow:loss = 1.8643103, step = 1680 (0.863 sec)
# INFO:tensorflow:global_step/sec: 115.915
# INFO:tensorflow:loss = 1.9442849, step = 1780 (0.849 sec)
# INFO:tensorflow:global_step/sec: 116.387
# INFO:tensorflow:loss = 1.9992093, step = 1880 (0.853 sec)
# INFO:tensorflow:global_step/sec: 117.981
# INFO:tensorflow:loss = 0.84340173, step = 1980 (0.862 sec)
# INFO:tensorflow:global_step/sec: 116.415
# INFO:tensorflow:loss = 1.3999553, step = 2080 (0.863 sec)
# INFO:tensorflow:global_step/sec: 116.361
# INFO:tensorflow:loss = 1.3380392, step = 2180 (0.862 sec)
# INFO:tensorflow:global_step/sec: 115.899
# INFO:tensorflow:loss = 1.3728077, step = 2280 (0.860 sec)
# INFO:tensorflow:global_step/sec: 116.038
# INFO:tensorflow:loss = 2.1034665, step = 2380 (0.853 sec)
# INFO:tensorflow:global_step/sec: 115.817
# INFO:tensorflow:loss = 0.6163197, step = 2480 (0.860 sec)
# INFO:tensorflow:global_step/sec: 117.406
# INFO:tensorflow:loss = 1.1017339, step = 2580 (0.851 sec)
# INFO:tensorflow:global_step/sec: 117.542
# INFO:tensorflow:loss = 0.8092398, step = 2680 (0.864 sec)
# INFO:tensorflow:global_step/sec: 115.912
# INFO:tensorflow:loss = 1.2600455, step = 2780 (0.856 sec)
# INFO:tensorflow:global_step/sec: 117.082
# INFO:tensorflow:loss = 0.76865685, step = 2880 (0.861 sec)
# INFO:tensorflow:global_step/sec: 116.134
# INFO:tensorflow:loss = 1.0409611, step = 2980 (0.853 sec)
# INFO:tensorflow:global_step/sec: 115.675
# INFO:tensorflow:loss = 0.75586826, step = 3080 (0.860 sec)
# INFO:tensorflow:global_step/sec: 116.865
# INFO:tensorflow:loss = 0.26077524, step = 3180 (0.864 sec)
# INFO:tensorflow:global_step/sec: 116.07
# INFO:tensorflow:loss = 0.48382896, step = 3280 (0.868 sec)
# INFO:tensorflow:global_step/sec: 115.815
# INFO:tensorflow:loss = 0.52090895, step = 3380 (0.865 sec)
# INFO:tensorflow:global_step/sec: 115.777
# INFO:tensorflow:loss = 0.7721269, step = 3480 (0.865 sec)
# INFO:tensorflow:global_step/sec: 115.569
# INFO:tensorflow:loss = 0.4785393, step = 3580 (0.939 sec)
# INFO:tensorflow:global_step/sec: 104.346
# INFO:tensorflow:loss = 0.1754051, step = 3680 (0.900 sec)
# INFO:tensorflow:global_step/sec: 112.438
# INFO:tensorflow:loss = 0.30311906, step = 3780 (0.896 sec)
# INFO:tensorflow:global_step/sec: 111.924
# INFO:tensorflow:loss = 0.4904368, step = 3880 (0.880 sec)
# INFO:tensorflow:global_step/sec: 112.573
# INFO:tensorflow:loss = 0.41491598, step = 3980 (0.901 sec)
# INFO:tensorflow:global_step/sec: 112.291
# INFO:tensorflow:loss = 0.1815145, step = 4080 (0.912 sec)
# INFO:tensorflow:global_step/sec: 109.703
# INFO:tensorflow:loss = 0.6088743, step = 4180 (0.874 sec)
# INFO:tensorflow:global_step/sec: 112.921
# INFO:tensorflow:loss = 0.0648282, step = 4280 (0.897 sec)
# INFO:tensorflow:global_step/sec: 111.744
# INFO:tensorflow:loss = 0.52809507, step = 4380 (0.873 sec)
# INFO:tensorflow:global_step/sec: 114.978
# INFO:tensorflow:loss = 1.2205373, step = 4480 (0.879 sec)
# INFO:tensorflow:global_step/sec: 114.211
# INFO:tensorflow:loss = 0.344849, step = 4580 (0.875 sec)
# INFO:tensorflow:global_step/sec: 114.241
# INFO:tensorflow:loss = 0.4588227, step = 4680 (0.877 sec)
# INFO:tensorflow:global_step/sec: 114.122
# INFO:tensorflow:loss = 0.28865096, step = 4780 (0.866 sec)
# INFO:tensorflow:global_step/sec: 113.917
# INFO:tensorflow:loss = 0.31868628, step = 4880 (0.869 sec)
# INFO:tensorflow:global_step/sec: 115.992
# INFO:tensorflow:loss = 0.6006744, step = 4980 (0.874 sec)
# INFO:tensorflow:global_step/sec: 114.491
# INFO:tensorflow:loss = 0.44203678, step = 5080 (0.878 sec)
# INFO:tensorflow:global_step/sec: 114.149
# INFO:tensorflow:loss = 0.40529352, step = 5180 (0.877 sec)
# INFO:tensorflow:global_step/sec: 114
# INFO:tensorflow:loss = 0.42185032, step = 5280 (0.876 sec)
# INFO:tensorflow:global_step/sec: 114.234
# INFO:tensorflow:loss = 0.35221273, step = 5380 (0.867 sec)
# INFO:tensorflow:global_step/sec: 114.005
# INFO:tensorflow:loss = 0.08945088, step = 5480 (0.864 sec)
# INFO:tensorflow:global_step/sec: 116.566
# INFO:tensorflow:loss = 0.43743694, step = 5580 (0.874 sec)
# INFO:tensorflow:global_step/sec: 114.868
# INFO:tensorflow:loss = 0.17748356, step = 5680 (0.874 sec)
# INFO:tensorflow:global_step/sec: 114.998
# INFO:tensorflow:loss = 0.47919425, step = 5780 (0.871 sec)
# INFO:tensorflow:global_step/sec: 114.638
# INFO:tensorflow:loss = 0.10897381, step = 5880 (0.882 sec)
# INFO:tensorflow:global_step/sec: 113.304
# INFO:tensorflow:loss = 0.17072238, step = 5980 (0.870 sec)
# INFO:tensorflow:global_step/sec: 113.524
# INFO:tensorflow:loss = 0.19984916, step = 6080 (0.869 sec)
# INFO:tensorflow:global_step/sec: 115.861
# INFO:tensorflow:loss = 0.23338053, step = 6180 (0.875 sec)
# INFO:tensorflow:global_step/sec: 114.537
# INFO:tensorflow:loss = 0.5512159, step = 6280 (0.874 sec)
# INFO:tensorflow:global_step/sec: 114.305
# INFO:tensorflow:loss = 0.23258278, step = 6380 (0.876 sec)
# INFO:tensorflow:global_step/sec: 114.421
# INFO:tensorflow:loss = 0.123423696, step = 6480 (0.876 sec)
# INFO:tensorflow:global_step/sec: 114.399
# INFO:tensorflow:loss = 0.26356062, step = 6580 (0.866 sec)
# INFO:tensorflow:global_step/sec: 113.901
# INFO:tensorflow:loss = 0.047544137, step = 6680 (0.874 sec)
# INFO:tensorflow:global_step/sec: 115.268
# INFO:tensorflow:loss = 0.095480725, step = 6780 (0.868 sec)
# INFO:tensorflow:global_step/sec: 116.069
# INFO:tensorflow:loss = 0.18164557, step = 6880 (0.861 sec)
# INFO:tensorflow:global_step/sec: 115.899
# INFO:tensorflow:loss = 0.25014278, step = 6980 (0.867 sec)
# INFO:tensorflow:global_step/sec: 115.247
# INFO:tensorflow:loss = 0.054938905, step = 7080 (0.883 sec)
# INFO:tensorflow:global_step/sec: 113.57
# INFO:tensorflow:loss = 0.047359243, step = 7180 (0.863 sec)
# INFO:tensorflow:global_step/sec: 113.987
# INFO:tensorflow:loss = 0.094636664, step = 7280 (0.877 sec)
# INFO:tensorflow:global_step/sec: 115.098
# INFO:tensorflow:loss = 0.1433759, step = 7380 (0.874 sec)
# INFO:tensorflow:global_step/sec: 114.764
# INFO:tensorflow:loss = 0.05790829, step = 7480 (0.879 sec)
# INFO:tensorflow:global_step/sec: 114.027
# INFO:tensorflow:loss = 0.13081647, step = 7580 (0.877 sec)
# INFO:tensorflow:global_step/sec: 114.189
# INFO:tensorflow:loss = 0.073344894, step = 7680 (0.874 sec)
# INFO:tensorflow:global_step/sec: 114.325
# INFO:tensorflow:loss = 0.040008456, step = 7780 (0.866 sec)
# INFO:tensorflow:global_step/sec: 113.788
# INFO:tensorflow:loss = 0.030433225, step = 7880 (0.875 sec)
# INFO:tensorflow:global_step/sec: 115.31
# INFO:tensorflow:loss = 0.094443426, step = 7980 (0.879 sec)
# INFO:tensorflow:global_step/sec: 113.283
# INFO:tensorflow:loss = 0.15505761, step = 8080 (0.910 sec)
# INFO:tensorflow:global_step/sec: 110.539
# INFO:tensorflow:loss = 0.102921575, step = 8180 (0.887 sec)
# INFO:tensorflow:global_step/sec: 112.558
# INFO:tensorflow:loss = 0.09533395, step = 8280 (0.948 sec)
# INFO:tensorflow:global_step/sec: 104.989
# INFO:tensorflow:loss = 0.058996074, step = 8380 (0.938 sec)
# INFO:tensorflow:global_step/sec: 105.432
# INFO:tensorflow:loss = 0.026653964, step = 8480 (0.956 sec)
# INFO:tensorflow:global_step/sec: 103.494
# INFO:tensorflow:loss = 0.14941074, step = 8580 (1.002 sec)
# INFO:tensorflow:global_step/sec: 100.992
# INFO:tensorflow:loss = 0.09237699, step = 8680 (1.086 sec)
# INFO:tensorflow:global_step/sec: 90.3675
# INFO:tensorflow:loss = 0.16794011, step = 8780 (1.050 sec)
# INFO:tensorflow:global_step/sec: 98.5999
# INFO:tensorflow:loss = 0.07486164, step = 8880 (0.921 sec)
# INFO:tensorflow:global_step/sec: 106.174
# INFO:tensorflow:loss = 0.10998437, step = 8980 (0.922 sec)
# INFO:tensorflow:global_step/sec: 109.509
# INFO:tensorflow:loss = 0.10592297, step = 9080 (0.887 sec)
# INFO:tensorflow:global_step/sec: 112.985
# INFO:tensorflow:loss = 0.028011214, step = 9180 (0.972 sec)
# INFO:tensorflow:global_step/sec: 101.53
# INFO:tensorflow:loss = 0.108579114, step = 9280 (0.967 sec)
# INFO:tensorflow:global_step/sec: 104.934
# INFO:tensorflow:loss = 0.0700132, step = 9380 (0.944 sec)
# INFO:tensorflow:global_step/sec: 105.218
# INFO:tensorflow:loss = 0.038536556, step = 9480 (0.975 sec)
# INFO:tensorflow:global_step/sec: 102.568
# INFO:tensorflow:loss = 0.023154251, step = 9580 (0.960 sec)
# INFO:tensorflow:global_step/sec: 100.144
# INFO:tensorflow:loss = 0.042749245, step = 9680 (1.067 sec)
# INFO:tensorflow:global_step/sec: 98.2363
# INFO:tensorflow:loss = 0.06641456, step = 9780 (0.901 sec)
# INFO:tensorflow:global_step/sec: 111.747
# INFO:tensorflow:loss = 0.027083984, step = 9880 (0.946 sec)
# INFO:tensorflow:global_step/sec: 105.913
# INFO:tensorflow:loss = 0.06320787, step = 9980 (0.901 sec)
# INFO:tensorflow:global_step/sec: 110.958
# INFO:tensorflow:loss = 0.027084475, step = 10080 (0.891 sec)
# INFO:tensorflow:global_step/sec: 112.105
# INFO:tensorflow:loss = 0.025309265, step = 10180 (0.880 sec)
# INFO:tensorflow:global_step/sec: 112.323
# INFO:tensorflow:loss = 0.016098183, step = 10280 (0.888 sec)
# INFO:tensorflow:global_step/sec: 113.245
# INFO:tensorflow:loss = 0.034129884, step = 10380 (0.903 sec)
# INFO:tensorflow:global_step/sec: 109.454
# INFO:tensorflow:loss = 0.025680302, step = 10480 (0.921 sec)
# INFO:tensorflow:global_step/sec: 110.048
# INFO:tensorflow:loss = 0.020101495, step = 10580 (0.917 sec)
# INFO:tensorflow:global_step/sec: 110.087
# INFO:tensorflow:loss = 0.031995907, step = 10680 (0.901 sec)
# INFO:tensorflow:global_step/sec: 110.2
# INFO:tensorflow:loss = 0.043213226, step = 10780 (0.883 sec)
# INFO:tensorflow:global_step/sec: 112.085
# INFO:tensorflow:loss = 0.009497432, step = 10880 (0.890 sec)
# INFO:tensorflow:global_step/sec: 112.82
# INFO:tensorflow:loss = 0.012942694, step = 10980 (0.897 sec)
# INFO:tensorflow:global_step/sec: 111.971
# INFO:tensorflow:loss = 0.033967093, step = 11080 (1.109 sec)
# INFO:tensorflow:global_step/sec: 84.0618
# INFO:tensorflow:loss = 0.04532107, step = 11180 (0.985 sec)
# INFO:tensorflow:global_step/sec: 110.665
# INFO:tensorflow:loss = 0.029143255, step = 11280 (0.919 sec)
# INFO:tensorflow:global_step/sec: 108.746
# INFO:tensorflow:loss = 0.02572213, step = 11380 (0.921 sec)
# INFO:tensorflow:global_step/sec: 107.457
# INFO:tensorflow:loss = 0.015904345, step = 11480 (0.962 sec)
# INFO:tensorflow:global_step/sec: 103.805
# INFO:tensorflow:loss = 0.013123925, step = 11580 (0.907 sec)
# INFO:tensorflow:global_step/sec: 111.486
# INFO:tensorflow:loss = 0.014860595, step = 11680 (0.900 sec)
# INFO:tensorflow:global_step/sec: 110.671
# INFO:tensorflow:loss = 0.006640563, step = 11780 (0.970 sec)
# INFO:tensorflow:global_step/sec: 100.327
# INFO:tensorflow:loss = 0.023425203, step = 11880 (0.993 sec)
# INFO:tensorflow:global_step/sec: 104.039
# INFO:tensorflow:loss = 0.01228255, step = 11980 (0.926 sec)
# INFO:tensorflow:global_step/sec: 104.075
# INFO:tensorflow:loss = 0.0145059, step = 12080 (0.928 sec)
# INFO:tensorflow:global_step/sec: 112.03
# INFO:tensorflow:loss = 0.020310134, step = 12180 (0.932 sec)
# INFO:tensorflow:global_step/sec: 104
# INFO:tensorflow:loss = 0.012012292, step = 12280 (1.032 sec)
# INFO:tensorflow:global_step/sec: 99.3624
# INFO:tensorflow:loss = 0.011996422, step = 12380 (0.934 sec)
# INFO:tensorflow:global_step/sec: 106.81
# INFO:tensorflow:loss = 0.014781339, step = 12480 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.701
# INFO:tensorflow:loss = 0.017252818, step = 12580 (0.891 sec)
# INFO:tensorflow:global_step/sec: 111.233
# INFO:tensorflow:loss = 0.031117609, step = 12680 (0.936 sec)
# INFO:tensorflow:global_step/sec: 107.706
# INFO:tensorflow:loss = 0.0064588976, step = 12780 (0.896 sec)
# INFO:tensorflow:global_step/sec: 111.753
# INFO:tensorflow:loss = 0.017601311, step = 12880 (0.895 sec)
# INFO:tensorflow:global_step/sec: 112.312
# INFO:tensorflow:loss = 0.0113300895, step = 12980 (0.897 sec)
# INFO:tensorflow:global_step/sec: 111.437
# INFO:tensorflow:loss = 0.007480585, step = 13080 (0.894 sec)
# INFO:tensorflow:global_step/sec: 110.165
# INFO:tensorflow:loss = 0.017956216, step = 13180 (1.008 sec)
# INFO:tensorflow:global_step/sec: 96.4275
# INFO:tensorflow:loss = 0.011724308, step = 13280 (1.028 sec)
# INFO:tensorflow:global_step/sec: 100.712
# INFO:tensorflow:loss = 0.0029069972, step = 13380 (0.940 sec)
# INFO:tensorflow:global_step/sec: 107.085
# INFO:tensorflow:loss = 0.012196321, step = 13480 (0.944 sec)
# INFO:tensorflow:global_step/sec: 106.033
# INFO:tensorflow:loss = 0.006901886, step = 13580 (0.918 sec)
# INFO:tensorflow:global_step/sec: 107.665
# INFO:tensorflow:loss = 0.013955839, step = 13680 (0.925 sec)
# INFO:tensorflow:global_step/sec: 109.175
# INFO:tensorflow:loss = 0.011130908, step = 13780 (0.896 sec)
# INFO:tensorflow:global_step/sec: 110.207
# INFO:tensorflow:loss = 0.0110156145, step = 13880 (0.900 sec)
# INFO:tensorflow:global_step/sec: 112.159
# INFO:tensorflow:loss = 0.010474708, step = 13980 (0.894 sec)
# INFO:tensorflow:global_step/sec: 112.284
# INFO:tensorflow:loss = 0.0033170646, step = 14080 (0.895 sec)
# INFO:tensorflow:global_step/sec: 111.596
# INFO:tensorflow:loss = 0.007957827, step = 14180 (0.900 sec)
# INFO:tensorflow:global_step/sec: 111.434
# INFO:tensorflow:loss = 0.0023830896, step = 14280 (0.907 sec)
# INFO:tensorflow:global_step/sec: 110.282
# INFO:tensorflow:loss = 0.0026379244, step = 14380 (0.891 sec)
# INFO:tensorflow:global_step/sec: 110.936
# INFO:tensorflow:loss = 0.0032215468, step = 14480 (0.896 sec)
# INFO:tensorflow:global_step/sec: 111.903
# INFO:tensorflow:loss = 0.009268449, step = 14580 (0.904 sec)
# INFO:tensorflow:global_step/sec: 111.02
# INFO:tensorflow:loss = 0.004240565, step = 14680 (0.921 sec)
# INFO:tensorflow:global_step/sec: 108.182
# INFO:tensorflow:loss = 0.008263059, step = 14780 (0.930 sec)
# INFO:tensorflow:global_step/sec: 106.839
# INFO:tensorflow:loss = 0.00433574, step = 14880 (0.934 sec)
# INFO:tensorflow:global_step/sec: 108.048
# INFO:tensorflow:loss = 0.0062811123, step = 14980 (0.941 sec)
# INFO:tensorflow:global_step/sec: 101.726
# INFO:tensorflow:loss = 0.0038327703, step = 15080 (0.984 sec)
# INFO:tensorflow:global_step/sec: 104.057
# INFO:tensorflow:loss = 0.011490442, step = 15180 (0.918 sec)
# INFO:tensorflow:global_step/sec: 107.891
# INFO:tensorflow:loss = 0.0071451887, step = 15280 (0.983 sec)
# INFO:tensorflow:global_step/sec: 105.255
# INFO:tensorflow:loss = 0.017136948, step = 15380 (0.903 sec)
# INFO:tensorflow:global_step/sec: 111.391
# INFO:tensorflow:loss = 0.0055036927, step = 15480 (0.897 sec)
# INFO:tensorflow:global_step/sec: 111.447
# INFO:tensorflow:loss = 0.004821257, step = 15580 (0.861 sec)
# INFO:tensorflow:global_step/sec: 114.971
# INFO:tensorflow:loss = 0.0038725787, step = 15680 (0.870 sec)
# INFO:tensorflow:global_step/sec: 115.711
# INFO:tensorflow:loss = 0.001120051, step = 15780 (0.897 sec)
# INFO:tensorflow:global_step/sec: 109.887
# INFO:tensorflow:loss = 0.006399326, step = 15880 (0.890 sec)
# INFO:tensorflow:global_step/sec: 114.44
# INFO:tensorflow:loss = 0.008177009, step = 15980 (0.873 sec)
# INFO:tensorflow:global_step/sec: 114.596
# INFO:tensorflow:loss = 0.0020965599, step = 16080 (0.873 sec)
# INFO:tensorflow:global_step/sec: 114.448
# INFO:tensorflow:loss = 0.0019979489, step = 16180 (0.866 sec)
# INFO:tensorflow:global_step/sec: 114.14
# INFO:tensorflow:loss = 0.0042326194, step = 16280 (0.864 sec)
# INFO:tensorflow:global_step/sec: 116.693
# INFO:tensorflow:loss = 0.004276527, step = 16380 (0.871 sec)
# INFO:tensorflow:global_step/sec: 114.84
# INFO:tensorflow:loss = 0.001050546, step = 16480 (0.879 sec)
# INFO:tensorflow:global_step/sec: 113.904
# INFO:tensorflow:loss = 0.0013851542, step = 16580 (0.893 sec)
# INFO:tensorflow:global_step/sec: 111.794
# INFO:tensorflow:loss = 0.004515864, step = 16680 (0.899 sec)
# INFO:tensorflow:global_step/sec: 111.075
# INFO:tensorflow:loss = 0.0036235885, step = 16780 (0.886 sec)
# INFO:tensorflow:global_step/sec: 111.734
# INFO:tensorflow:loss = 0.0034443112, step = 16880 (0.894 sec)
# INFO:tensorflow:global_step/sec: 112.513
# INFO:tensorflow:loss = 0.004030059, step = 16980 (0.897 sec)
# INFO:tensorflow:global_step/sec: 111.852
# INFO:tensorflow:loss = 0.005280808, step = 17080 (0.892 sec)
# INFO:tensorflow:global_step/sec: 112.569
# INFO:tensorflow:loss = 0.0025425544, step = 17180 (0.894 sec)
# INFO:tensorflow:global_step/sec: 111.736
# INFO:tensorflow:loss = 0.002331301, step = 17280 (0.915 sec)
# INFO:tensorflow:global_step/sec: 108.234
# INFO:tensorflow:loss = 0.0026290952, step = 17380 (0.897 sec)
# INFO:tensorflow:global_step/sec: 111.196
# INFO:tensorflow:loss = 0.0046535954, step = 17480 (0.889 sec)
# INFO:tensorflow:global_step/sec: 113.122
# INFO:tensorflow:loss = 0.0034699126, step = 17580 (0.891 sec)
# INFO:tensorflow:global_step/sec: 112.398
# INFO:tensorflow:loss = 0.0035710898, step = 17680 (0.899 sec)
# INFO:tensorflow:global_step/sec: 111.532
# INFO:tensorflow:loss = 0.0051810876, step = 17780 (0.908 sec)
# INFO:tensorflow:global_step/sec: 108.573
# INFO:tensorflow:loss = 0.0035858918, step = 17880 (0.917 sec)
# INFO:tensorflow:global_step/sec: 110.499
# INFO:tensorflow:loss = 0.0024185532, step = 17980 (0.897 sec)
# INFO:tensorflow:global_step/sec: 110.226
# INFO:tensorflow:loss = 0.00226442, step = 18080 (0.917 sec)
# INFO:tensorflow:global_step/sec: 109.207
# INFO:tensorflow:loss = 0.002493695, step = 18180 (0.908 sec)
# INFO:tensorflow:global_step/sec: 111.1
# INFO:tensorflow:loss = 0.0018305652, step = 18280 (0.901 sec)
# INFO:tensorflow:global_step/sec: 110.442
# INFO:tensorflow:loss = 0.002879897, step = 18380 (0.944 sec)
# INFO:tensorflow:global_step/sec: 106.542
# INFO:tensorflow:loss = 0.0014192462, step = 18480 (0.904 sec)
# INFO:tensorflow:global_step/sec: 110.894
# INFO:tensorflow:loss = 0.0015700937, step = 18580 (0.888 sec)
# INFO:tensorflow:global_step/sec: 111.064
# INFO:tensorflow:loss = 0.00198727, step = 18680 (0.935 sec)
# INFO:tensorflow:global_step/sec: 107.666
# INFO:tensorflow:loss = 0.0006596165, step = 18780 (0.914 sec)
# INFO:tensorflow:global_step/sec: 109.657
# INFO:tensorflow:loss = 0.0026301935, step = 18880 (0.905 sec)
# INFO:tensorflow:global_step/sec: 110.484
# INFO:tensorflow:loss = 0.0045993887, step = 18980 (0.971 sec)
# INFO:tensorflow:global_step/sec: 101.272
# INFO:tensorflow:loss = 0.00076149416, step = 19080 (0.961 sec)
# INFO:tensorflow:global_step/sec: 103.763
# INFO:tensorflow:loss = 0.0013865799, step = 19180 (0.929 sec)
# INFO:tensorflow:global_step/sec: 108.373
# INFO:tensorflow:loss = 0.0017714709, step = 19280 (0.917 sec)
# INFO:tensorflow:global_step/sec: 110.151
# INFO:tensorflow:loss = 0.0012486444, step = 19380 (0.906 sec)
# INFO:tensorflow:global_step/sec: 110.483
# INFO:tensorflow:loss = 0.0011954706, step = 19480 (0.923 sec)
# INFO:tensorflow:global_step/sec: 108.386
# INFO:tensorflow:loss = 0.0030450884, step = 19580 (0.913 sec)
# INFO:tensorflow:global_step/sec: 109.955
# INFO:tensorflow:loss = 0.0018553562, step = 19680 (0.915 sec)
# INFO:tensorflow:global_step/sec: 109.214
# INFO:tensorflow:loss = 0.000983977, step = 19780 (0.899 sec)
# INFO:tensorflow:global_step/sec: 109.76
# INFO:tensorflow:loss = 0.00062166306, step = 19880 (0.910 sec)
# INFO:tensorflow:global_step/sec: 110.745
# INFO:tensorflow:loss = 0.0016425285, step = 19980 (0.905 sec)
# INFO:tensorflow:global_step/sec: 110.95
# INFO:tensorflow:loss = 0.001947523, step = 20080 (0.907 sec)
# INFO:tensorflow:global_step/sec: 110.38
# INFO:tensorflow:loss = 0.0016616487, step = 20180 (0.925 sec)
# INFO:tensorflow:global_step/sec: 107.697
# INFO:tensorflow:loss = 0.0008525751, step = 20280 (0.916 sec)
# INFO:tensorflow:global_step/sec: 109.762
# INFO:tensorflow:loss = 0.00020770378, step = 20380 (0.918 sec)
# INFO:tensorflow:global_step/sec: 107.723
# INFO:tensorflow:loss = 0.0013433935, step = 20480 (0.911 sec)
# INFO:tensorflow:global_step/sec: 110.257
# INFO:tensorflow:loss = 0.000941799, step = 20580 (0.919 sec)
# INFO:tensorflow:global_step/sec: 108.483
# INFO:tensorflow:loss = 0.00051640824, step = 20680 (0.921 sec)
# INFO:tensorflow:global_step/sec: 109.395
# INFO:tensorflow:loss = 0.0010997539, step = 20780 (0.915 sec)
# INFO:tensorflow:global_step/sec: 109.006
# INFO:tensorflow:loss = 0.00043496583, step = 20880 (0.914 sec)
# INFO:tensorflow:global_step/sec: 109.721
# INFO:tensorflow:loss = 0.0032741814, step = 20980 (0.903 sec)
# INFO:tensorflow:global_step/sec: 109.337
# INFO:tensorflow:loss = 0.0016739173, step = 21080 (0.916 sec)
# INFO:tensorflow:global_step/sec: 109.943
# INFO:tensorflow:loss = 0.0009836646, step = 21180 (0.908 sec)
# INFO:tensorflow:global_step/sec: 110.663
# INFO:tensorflow:loss = 0.0011111934, step = 21280 (0.920 sec)
# INFO:tensorflow:global_step/sec: 108.652
# INFO:tensorflow:loss = 0.0007037668, step = 21380 (0.925 sec)
# INFO:tensorflow:global_step/sec: 108.147
# INFO:tensorflow:loss = 0.0007543943, step = 21480 (0.924 sec)
# INFO:tensorflow:global_step/sec: 107.934
# INFO:tensorflow:loss = 0.00027056536, step = 21580 (0.922 sec)
# INFO:tensorflow:global_step/sec: 105.872
# INFO:tensorflow:loss = 0.0002521699, step = 21680 (0.927 sec)
# INFO:tensorflow:global_step/sec: 108.561
# INFO:tensorflow:loss = 0.00067488867, step = 21780 (0.946 sec)
# INFO:tensorflow:global_step/sec: 107.505
# INFO:tensorflow:loss = 0.0005173725, step = 21880 (0.915 sec)
# INFO:tensorflow:global_step/sec: 109.759
# INFO:tensorflow:loss = 0.0008621158, step = 21980 (0.917 sec)
# INFO:tensorflow:global_step/sec: 108.887
# INFO:tensorflow:loss = 0.00048097887, step = 22080 (0.920 sec)
# INFO:tensorflow:global_step/sec: 108.953
# INFO:tensorflow:loss = 0.00066504686, step = 22180 (0.904 sec)
# INFO:tensorflow:global_step/sec: 109.436
# INFO:tensorflow:loss = 0.0002449886, step = 22280 (0.918 sec)
# INFO:tensorflow:global_step/sec: 109.4
# INFO:tensorflow:loss = 0.0014023345, step = 22380 (0.917 sec)
# INFO:tensorflow:global_step/sec: 109.414
# INFO:tensorflow:loss = 0.00045599884, step = 22480 (0.933 sec)
# INFO:tensorflow:global_step/sec: 107.194
# INFO:tensorflow:loss = 0.0006470336, step = 22580 (0.915 sec)
# INFO:tensorflow:global_step/sec: 109.229
# INFO:tensorflow:loss = 0.00044389782, step = 22680 (0.913 sec)
# INFO:tensorflow:global_step/sec: 109.614
# INFO:tensorflow:loss = 0.0005595925, step = 22780 (0.902 sec)
# INFO:tensorflow:global_step/sec: 109.429
# INFO:tensorflow:loss = 0.0004793037, step = 22880 (0.914 sec)
# INFO:tensorflow:global_step/sec: 110.42
# INFO:tensorflow:loss = 0.0004521671, step = 22980 (0.907 sec)
# INFO:tensorflow:global_step/sec: 110.526
# INFO:tensorflow:loss = 4.089984e-05, step = 23080 (0.911 sec)
# INFO:tensorflow:global_step/sec: 109.92
# INFO:tensorflow:loss = 0.00036955776, step = 23180 (0.909 sec)
# INFO:tensorflow:global_step/sec: 110.349
# INFO:tensorflow:loss = 0.0003564204, step = 23280 (0.910 sec)
# INFO:tensorflow:global_step/sec: 109.892
# INFO:tensorflow:loss = 0.00034925886, step = 23380 (0.895 sec)
# INFO:tensorflow:global_step/sec: 110.298
# INFO:tensorflow:loss = 0.00012428634, step = 23480 (0.903 sec)
# INFO:tensorflow:global_step/sec: 111.269
# INFO:tensorflow:loss = 0.00024029042, step = 23580 (0.911 sec)
# INFO:tensorflow:global_step/sec: 110.286
# INFO:tensorflow:loss = 0.00022307952, step = 23680 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.057
# INFO:tensorflow:loss = 0.00011878895, step = 23780 (0.916 sec)
# INFO:tensorflow:global_step/sec: 108.582
# INFO:tensorflow:loss = 8.971237e-05, step = 23880 (0.935 sec)
# INFO:tensorflow:global_step/sec: 106.342
# 2022-11-23 12:28:42.192234: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:loss = 0.00050202495, step = 23980 (0.949 sec)
# INFO:tensorflow:global_step/sec: 103.767
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 24000...
# INFO:tensorflow:Saving checkpoints for 24000 into /var/folders/tb/x7hcv5j94gn9b46c7qc1vfth0000gn/T/tmp54lx3zxg/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 24000...
# INFO:tensorflow:Loss for final step: 0.00035642966.
# INFO:tensorflow:Calling model_fn.
# Exception ignored in: <function CapturableResource.__del__ at 0x13010b670>
# Traceback (most recent call last):
#   File "/Users/hanhyeongu/miniforge3/envs/hg/lib/python3.8/site-packages/tensorflow/python/training/tracking/tracking.py", line 269, in __del__
#     with self._destruction_context():
# AttributeError: 'TreeEnsemble' object has no attribute '_destruction_context'
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2022-11-23T12:28:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/tb/x7hcv5j94gn9b46c7qc1vfth0000gn/T/tmp54lx3zxg/model.ckpt-24000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2022-11-23 12:28:43.752840: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-23 12:28:43.752862: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-11-23 12:28:43.759749: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:28:43.767725: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:28:43.773923: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:28:43.782942: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:28:43.790762: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:28:43.796203: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-11-23 12:28:43.938706: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# INFO:tensorflow:Inference Time : 0.24059s
# INFO:tensorflow:Finished evaluation at 2022-11-23-12:28:43
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 10.688785, global_step = 24000, label/mean = 23.611393, loss = 10.607884, prediction/mean = 22.829304
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 24000: /var/folders/tb/x7hcv5j94gn9b46c7qc1vfth0000gn/T/tmp54lx3zxg/model.ckpt-24000
# {'average_loss': 10.688785, 'label/mean': 23.611393, 'loss': 10.607884, 'prediction/mean': 22.829304, 'global_step': 24000}
# 평균 손실 10.6888
